# %% [markdown]
# ## cGEM modeling pipeline
#
# Inputs
# - MAGs and metadata (taxonomy, relative abundance, etc.)
# - Medium composition (tsv file)
#
# Steps
# 1. Reconstruct individual GEMs with CarveME -> save xmls
# 2. Generate MICOM's taxonomy table for reconstructed models -> save tsv
# 3. Build Community model with MICOM -> save pickle
# 4. Run MICOM's grow workflow and get exchanges -> save tsv
# 5. Run Visualization module to get three different plots -> save pngs
#
# __NOTES__:
#
# * Currently using the SCIP solver

# %% [markdown]
# ## Input files
#
# 1. Directory with gene predictions translated to proteins for each MAG as faa files, with file names as MAG IDs
# 2. Relative abundance as tsv file, with MAG ID, abundance, and taxonomy
# 3. Medium composition as tsv file, with exchange reaction ID, and maximum uptake rate
# 4. Universal model file as xml

# %%
import pandas as pd

abundances = pd.read_csv("../tests/data/abundances.tsv", sep="\t", index_col=0)
abundances.head()
# Out:
#                              taxonomy  abundance
# id
# TARA_ARC_108_MAG_00080    Alteromonas         30
# TARA_ARC_108_MAG_00083  Sulfitobacter         40
# TARA_ARC_108_MAG_00201   Polaribacter         10
# TARA_ARC_108_MAG_00174   Marinobacter         20

# %% [markdown]
# ## Reconstruction of individual GEMs

# %%
# %%bash
#
# docker run \
#   -v /home/robaina/Documents/NewAtlantis/microcom:/app/microcom \
#   -v /home/robaina/Documents/NewAtlantis/microcom/tests/data/genome_table.tsv:/app/config.tsv \
#   -v /home/robaina/Documents/NewAtlantis/microcom/tests/test_docker_carveme:/app/results \
#   ghcr.io/new-atlantis-labs/carveme:latest \
#   --config /app/config.tsv \
#   --outdir /app/results \
#   --processes 10
# Out:
# diamond v2.1.11.165 (C) Max Planck Society for the Advancement of Science, Benjamin Buchfink, University of Tuebingen
# Documentation, support and updates available at http://www.diamondsearch.org
# Please cite: http://dx.doi.org/10.1038/s41592-021-01101-x Nature Methods (2021)
#
# #CPU threads: 16
# Scoring parameters: (Matrix=BLOSUM62 Lambda=0.267 K=0.041 Penalties=11/1)
# diamond v2.1.11.165 (C) Max Planck Society for the Advancement of Science, Benjamin Buchfink, University of Tuebingen
# Documentation, support and updates available at http://www.diamondsearch.org
# Please cite: http://dx.doi.org/10.1038/s41592-021-01101-x Nature Methods (2021)
#
# #CPU threads: 16
# Scoring parameters: (Matrix=BLOSUM62 Lambda=0.267 K=0.041 Penalties=11/1)
# Database input file: /opt/conda/envs/carveme/lib/python3.12/site-packages/carveme/data/generated/bigg_proteins.faa
# Opening the database file... Database input file: /opt/conda/envs/carveme/lib/python3.12/site-packages/carveme/data/generated/bigg_proteins.faa
# Opening the database file...  [0.002s]
# Loading sequences...  [0.002s]
# Loading sequences... Error: Error detecting input file format. Input file seems to be empty.
# Failed to run diamond.
# Error: Error detecting input file format. Input file seems to be empty.
# Failed to run diamond.
#  [0.117s]
# Masking sequences...  [0.117s]
# Masking sequences...  [0.157s]
# Writing sequences...  [0.009s]
# Hashing sequences...  [0.167s]
# Writing sequences...  [0.004s]
# Loading sequences...  [0s]
# Writing trailer...  [0s]
# Closing the input file...  [0s]
# Closing the database file...  [0.004s]
#
# Database sequences  26727
#   Database letters  11170577
#      Database hash  24c02a79262bb879015f9aacd7495165
#         Total time  0.296000s
#  [0.008s]
# Hashing sequences...  [0.002s]
# Loading sequences...  [0s]
# Writing trailer...  [0s]
# Closing the input file...  [0s]
# Closing the database file...  [0.001s]
#
# Database sequences  26727
#   Database letters  11170577
#      Database hash  24c02a79262bb879015f9aacd7495165
#         Total time  0.300000s
# /opt/conda/envs/carveme/lib/python3.12/site-packages/reframed/solvers/scip_solver.py:73: UserWarning: linked SCIP 9.02 is not recommended for this version of PySCIPOpt - use version 9.2.1
#   self.problem = Model()
# /opt/conda/envs/carveme/lib/python3.12/site-packages/reframed/solvers/scip_solver.py:73: UserWarning: linked SCIP 9.02 is not recommended for this version of PySCIPOpt - use version 9.2.1
#   self.problem = Model()
# /opt/conda/envs/carveme/lib/python3.12/site-packages/reframed/solvers/scip_solver.py:73: UserWarning: linked SCIP 9.02 is not recommended for this version of PySCIPOpt - use version 9.2.1
#   self.problem = Model()
# /opt/conda/envs/carveme/lib/python3.12/site-packages/reframed/solvers/scip_solver.py:73: UserWarning: linked SCIP 9.02 is not recommended for this version of PySCIPOpt - use version 9.2.1
#   self.problem = Model()
# Error while terminating subprocess (pid=82055):
# Running diamond for the first time, please wait while we build the internal database...
# Running diamond for the first time, please wait while we build the internal database...
#
# Processing TARA_ARC_108_MAG_00083.fasta
#   Universe: /app/microcom/data/universes/universal_prokaryote_curated.xml
#   Media: /app/microcom/data/media/media_db.tsv
#   Medium ID: MARINE
# Completed processing TARA_ARC_108_MAG_00083.fasta
#
# Processing TARA_ARC_108_MAG_00174.fasta
#   Universe: /app/microcom/data/universes/universal_prokaryote_curated.xml
#   Media: /app/microcom/data/media/media_db.tsv
#   Medium ID: MARINE
# Completed processing TARA_ARC_108_MAG_00174.fasta
#
# Processing TARA_ARC_108_MAG_00080.fasta
#   Universe: /app/microcom/data/universes/universal_prokaryote_curated.xml
#   Media: /app/microcom/data/media/media_db.tsv
#   Medium ID: MARINE
# Completed processing TARA_ARC_108_MAG_00080.fasta
#
# Processing TARA_ARC_108_MAG_00201.fasta
#   Universe: /app/microcom/data/universes/universal_prokaryote_curated.xml
#   Media: /app/microcom/data/media/media_db.tsv
#   Medium ID: MARINE
# Completed processing TARA_ARC_108_MAG_00201.fasta
#
# Processed 4 genomes successfully

# %% [markdown]
# ## Prepare medium file from media database for MICOM

# %%
# %%bash
#
# DATA_DIR="/home/robaina/Documents/NewAtlantis/microcom/data"
# RESULTS_DIR="/home/robaina/Documents/NewAtlantis/microcom/tests/test_docker_micom"
# mkdir -p "${RESULTS_DIR}"
#
# docker run --rm \
#   -v "${DATA_DIR}:/app/data" \
#   -v "${RESULTS_DIR}:/app/results" \
#   ghcr.io/new-atlantis-labs/micom:latest \
#   get_medium_from_media_db \
#   --media-db /app/data/media/media_db.tsv \
#   --medium-id "MARINE" \
#   --compartment "m" \
#   --max-uptake 10.0 \
#   --outfile /app/results/marine_media.tsv

# %% [markdown]
# ## Making MICOM's taxa table

# %%
# %%bash
#
# DATA_DIR="/home/robaina/Documents/NewAtlantis/microcom/tests/data"
# GEMS_DIR="/home/robaina/Documents/NewAtlantis/microcom/tests/test_docker_carveme/gems"
# RESULTS_DIR="/home/robaina/Documents/NewAtlantis/microcom/tests/test_docker_micom"
# mkdir -p "${RESULTS_DIR}"
#
# docker run --rm \
#   -v "${DATA_DIR}:/app/data" \
#   -v "${GEMS_DIR}:/app/gems_scip" \
#   -v "${RESULTS_DIR}:/app/results" \
#   ghcr.io/new-atlantis-labs/micom:latest \
#   build_taxa_table \
#     --sample_id "TARA_ARC_108" \
#     --abundances /app/data/abundances.tsv \
#     --gems_dir /app/gems_scip \
#     --out_taxatable /app/results/micom_database.tsv

# %%
import pandas as pd

taxa = pd.read_csv("../tests/test_docker_micom/micom_database.tsv", sep="\t", index_col=0)
taxa.head()
# Out:
#                                   id  abundance       taxonomy  \
# sample_id
# TARA_ARC_108  TARA_ARC_108_MAG_00174         20   Marinobacter
# TARA_ARC_108  TARA_ARC_108_MAG_00083         40  Sulfitobacter
# TARA_ARC_108  TARA_ARC_108_MAG_00080         30    Alteromonas
# TARA_ARC_108  TARA_ARC_108_MAG_00201         10   Polaribacter
#
#                                                    file
# sample_id
# TARA_ARC_108  /app/gems_scip/TARA_ARC_108_MAG_00174.xml
# TARA_ARC_108  /app/gems_scip/TARA_ARC_108_MAG_00083.xml
# TARA_ARC_108  /app/gems_scip/TARA_ARC_108_MAG_00080.xml
# TARA_ARC_108  /app/gems_scip/TARA_ARC_108_MAG_00201.xml

# %% [markdown]
# ## Build community model

# %%
# %%bash
#
# GEMS_DIR="/home/robaina/Documents/NewAtlantis/microcom/tests/test_docker_carveme/gems"
# INPUT_DIR="/home/robaina/Documents/NewAtlantis/microcom/tests/test_docker_micom"
# RESULTS_DIR="/home/robaina/Documents/NewAtlantis/microcom/test_docker_micom"
# mkdir -p "${RESULTS_DIR}"
#
# docker run --rm \
#   -v "${INPUT_DIR}:/app/data" \
#   -v "${RESULTS_DIR}:/app/results" \
#   -v "${GEMS_DIR}:/app/gems_scip" \
#   ghcr.io/new-atlantis-labs/micom:latest \
#   build_cgem \
#   --taxa_table /app/data/micom_database.tsv \
#   --outdir /app/results \
#   --abundance_cutoff 0.01 \
#   --gems_dir /app/gems_scip \
#   --threads 10 \
#   --solver "hybrid"
# Out:
# Ignoring reaction 'EX_h2_e' since it already exists.
# Ignoring reaction 'EX_h_e' since it already exists.
# Ignoring reaction 'EX_photon_e' since it already exists.
# Ignoring reaction 'EX_12ppd__S_e' since it already exists.
# Ignoring reaction 'EX_23dappa_e' since it already exists.
# Ignoring reaction 'EX_26dap__M_e' since it already exists.
# Ignoring reaction 'EX_3amp_e' since it already exists.
# Ignoring reaction 'EX_3gmp_e' since it already exists.
# Ignoring reaction 'EX_3hcinnm_e' since it already exists.
# Ignoring reaction 'EX_3hpp_e' since it already exists.
# Ignoring reaction 'EX_3ump_e' since it already exists.
# Ignoring reaction 'EX_5dglcn_e' since it already exists.
# Ignoring reaction 'EX_LalaDglu_e' since it already exists.
# Ignoring reaction 'EX_acgal_e' since it already exists.
# Ignoring reaction 'EX_acgal1p_e' since it already exists.
# Ignoring reaction 'EX_acgam_e' since it already exists.
# Ignoring reaction 'EX_acmana_e' since it already exists.
# Ignoring reaction 'EX_ade_e' since it already exists.
# Ignoring reaction 'EX_adn_e' since it already exists.
# Ignoring reaction 'EX_agm_e' since it already exists.
# Ignoring reaction 'EX_ala_B_e' since it already exists.
# Ignoring reaction 'EX_alaala_e' since it already exists.
# Ignoring reaction 'EX_all__D_e' since it already exists.
# Ignoring reaction 'EX_amp_e' since it already exists.
# Ignoring reaction 'EX_arab__L_e' since it already exists.
# Ignoring reaction 'EX_arbt_e' since it already exists.
# Ignoring reaction 'EX_ascb__L_e' since it already exists.
# Ignoring reaction 'EX_asn__L_e' since it already exists.
# Ignoring reaction 'EX_asp__L_e' since it already exists.
# Ignoring reaction 'EX_btn_e' since it already exists.
# Ignoring reaction 'EX_ca2_e' since it already exists.
# Ignoring reaction 'EX_chtbs_e' since it already exists.
# Ignoring reaction 'EX_cl_e' since it already exists.
# Ignoring reaction 'EX_cmp_e' since it already exists.
# Ignoring reaction 'EX_co2_e' since it already exists.
# Ignoring reaction 'EX_cu2_e' since it already exists.
# Ignoring reaction 'EX_cyan_e' since it already exists.
# Ignoring reaction 'EX_cys__L_e' since it already exists.
# Ignoring reaction 'EX_cytd_e' since it already exists.
# Ignoring reaction 'EX_dad_2_e' since it already exists.
# Ignoring reaction 'EX_ddca_e' since it already exists.
# Ignoring reaction 'EX_dgsn_e' since it already exists.
# Ignoring reaction 'EX_dha_e' since it already exists.
# Ignoring reaction 'EX_din_e' since it already exists.
# Ignoring reaction 'EX_dmso_e' since it already exists.
# Ignoring reaction 'EX_dump_e' since it already exists.
# Ignoring reaction 'EX_enter_e' since it already exists.
# Ignoring reaction 'EX_fald_e' since it already exists.
# Ignoring reaction 'EX_fe2_e' since it already exists.
# Ignoring reaction 'EX_fe3_e' since it already exists.
# Ignoring reaction 'EX_fe3dcit_e' since it already exists.
# Ignoring reaction 'EX_g3pc_e' since it already exists.
# Ignoring reaction 'EX_g6p_e' since it already exists.
# Ignoring reaction 'EX_gal_e' since it already exists.
# Ignoring reaction 'EX_gal_bD_e' since it already exists.
# Ignoring reaction 'EX_galct__D_e' since it already exists.
# Ignoring reaction 'EX_gam_e' since it already exists.
# Ignoring reaction 'EX_gam6p_e' since it already exists.
# Ignoring reaction 'EX_gbbtn_e' since it already exists.
# Ignoring reaction 'EX_gdp_e' since it already exists.
# Ignoring reaction 'EX_glcr_e' since it already exists.
# Ignoring reaction 'EX_glyald_e' since it already exists.
# Ignoring reaction 'EX_glyc3p_e' since it already exists.
# Ignoring reaction 'EX_gsn_e' since it already exists.
# Ignoring reaction 'EX_gthox_e' since it already exists.
# Ignoring reaction 'EX_gua_e' since it already exists.
# Ignoring reaction 'EX_h2o2_e' since it already exists.
# Ignoring reaction 'EX_hdca_e' since it already exists.
# Ignoring reaction 'EX_indole_e' since it already exists.
# Ignoring reaction 'EX_inost_e' since it already exists.
# Ignoring reaction 'EX_ins_e' since it already exists.
# Ignoring reaction 'EX_k_e' since it already exists.
# Ignoring reaction 'EX_lac__L_e' since it already exists.
# Ignoring reaction 'EX_lipoate_e' since it already exists.
# Ignoring reaction 'EX_lyx__L_e' since it already exists.
# Ignoring reaction 'EX_malthx_e' since it already exists.
# Ignoring reaction 'EX_malttr_e' since it already exists.
# Ignoring reaction 'EX_maltttr_e' since it already exists.
# Ignoring reaction 'EX_melib_e' since it already exists.
# Ignoring reaction 'EX_met__L_e' since it already exists.
# Ignoring reaction 'EX_metsox_S__L_e' since it already exists.
# Ignoring reaction 'EX_mnl_e' since it already exists.
# Ignoring reaction 'EX_mso3_e' since it already exists.
# Ignoring reaction 'EX_n2o_e' since it already exists.
# Ignoring reaction 'EX_nac_e' since it already exists.
# Ignoring reaction 'EX_no_e' since it already exists.
# Ignoring reaction 'EX_no2_e' since it already exists.
# Ignoring reaction 'EX_no3_e' since it already exists.
# Ignoring reaction 'EX_ocdcea_e' since it already exists.
# Ignoring reaction 'EX_orot_e' since it already exists.
# Ignoring reaction 'EX_pacald_e' since it already exists.
# Ignoring reaction 'EX_pheme_e' since it already exists.
# Ignoring reaction 'EX_pnto__R_e' since it already exists.
# Ignoring reaction 'EX_ppa_e' since it already exists.
# Ignoring reaction 'EX_ppal_e' since it already exists.
# Ignoring reaction 'EX_pppn_e' since it already exists.
# Ignoring reaction 'EX_progly_e' since it already exists.
# Ignoring reaction 'EX_pser__L_e' since it already exists.
# Ignoring reaction 'EX_ptrc_e' since it already exists.
# Ignoring reaction 'EX_pydam_e' since it already exists.
# Ignoring reaction 'EX_pydx_e' since it already exists.
# Ignoring reaction 'EX_pyr_e' since it already exists.
# Ignoring reaction 'EX_rmn_e' since it already exists.
# Ignoring reaction 'EX_sbt__D_e' since it already exists.
# Ignoring reaction 'EX_sel_e' since it already exists.
# Ignoring reaction 'EX_ser__D_e' since it already exists.
# Ignoring reaction 'EX_skm_e' since it already exists.
# Ignoring reaction 'EX_so3_e' since it already exists.
# Ignoring reaction 'EX_so4_e' since it already exists.
# Ignoring reaction 'EX_spmd_e' since it already exists.
# Ignoring reaction 'EX_taur_e' since it already exists.
# Ignoring reaction 'EX_thm_e' since it already exists.
# Ignoring reaction 'EX_thr__L_e' since it already exists.
# Ignoring reaction 'EX_ttdca_e' since it already exists.
# Ignoring reaction 'EX_tym_e' since it already exists.
# Ignoring reaction 'EX_tyr__L_e' since it already exists.
# Ignoring reaction 'EX_tyrp_e' since it already exists.
# Ignoring reaction 'EX_udpg_e' since it already exists.
# Ignoring reaction 'EX_urea_e' since it already exists.
# Ignoring reaction 'EX_uri_e' since it already exists.
# Ignoring reaction 'EX_val__L_e' since it already exists.
# Ignoring reaction 'EX_xan_e' since it already exists.
# Ignoring reaction 'EX_xmp_e' since it already exists.
# Ignoring reaction 'EX_xtsn_e' since it already exists.
# Ignoring reaction 'EX_xyl__D_e' since it already exists.
# Ignoring reaction 'EX_zn2_e' since it already exists.
# Ignoring reaction 'EX_5mtr_e' since it already exists.
# Ignoring reaction 'EX_acac_e' since it already exists.
# Ignoring reaction 'EX_acald_e' since it already exists.
# Ignoring reaction 'EX_ac_e' since it already exists.
# Ignoring reaction 'EX_alltn_e' since it already exists.
# Ignoring reaction 'EX_arg__L_e' since it already exists.
# Ignoring reaction 'EX_but_e' since it already exists.
# Ignoring reaction 'EX_cgly_e' since it already exists.
# Ignoring reaction 'EX_cit_e' since it already exists.
# Ignoring reaction 'EX_crn_e' since it already exists.
# Ignoring reaction 'EX_cynt_e' since it already exists.
# Ignoring reaction 'EX_lac__D_e' since it already exists.
# Ignoring reaction 'EX_dca_e' since it already exists.
# Ignoring reaction 'EX_dcmp_e' since it already exists.
# Ignoring reaction 'EX_2ddglcn_e' since it already exists.
# Ignoring reaction 'EX_dgmp_e' since it already exists.
# Ignoring reaction 'EX_duri_e' since it already exists.
# Ignoring reaction 'EX_etha_e' since it already exists.
# Ignoring reaction 'EX_etoh_e' since it already exists.
# Ignoring reaction 'EX_for_e' since it already exists.
# Ignoring reaction 'EX_g3pe_e' since it already exists.
# Ignoring reaction 'EX_galur_e' since it already exists.
# Ignoring reaction 'EX_glcur_e' since it already exists.
# Ignoring reaction 'EX_gln__L_e' since it already exists.
# Ignoring reaction 'EX_glu__L_e' since it already exists.
# Ignoring reaction 'EX_glyb_e' since it already exists.
# Ignoring reaction 'EX_glyclt_e' since it already exists.
# Ignoring reaction 'EX_glyc_e' since it already exists.
# Ignoring reaction 'EX_gthrd_e' since it already exists.
# Ignoring reaction 'EX_gtp_e' since it already exists.
# Ignoring reaction 'EX_h2s_e' since it already exists.
# Ignoring reaction 'EX_hdcea_e' since it already exists.
# Ignoring reaction 'EX_his__L_e' since it already exists.
# Ignoring reaction 'EX_hxan_e' since it already exists.
# Ignoring reaction 'EX_ile__L_e' since it already exists.
# Ignoring reaction 'EX_imp_e' since it already exists.
# Ignoring reaction 'EX_lcts_e' since it already exists.
# Ignoring reaction 'EX_lys__L_e' since it already exists.
# Ignoring reaction 'EX_maltpt_e' since it already exists.
# Ignoring reaction 'EX_mal__L_e' since it already exists.
# Ignoring reaction 'EX_met__D_e' since it already exists.
# Ignoring reaction 'EX_mg2_e' since it already exists.
# Ignoring reaction 'EX_mn2_e' since it already exists.
# Ignoring reaction 'EX_mobd_e' since it already exists.
# Ignoring reaction 'EX_orn_e' since it already exists.
# Ignoring reaction 'EX_pi_e' since it already exists.
# Ignoring reaction 'EX_pro__L_e' since it already exists.
# Ignoring reaction 'EX_pydxn_e' since it already exists.
# Ignoring reaction 'EX_quin_e' since it already exists.
# Ignoring reaction 'EX_rib__D_e' since it already exists.
# Ignoring reaction 'EX_ser__L_e' since it already exists.
# Ignoring reaction 'EX_slnt_e' since it already exists.
# Ignoring reaction 'EX_so2_e' since it already exists.
# Ignoring reaction 'EX_succ_e' since it already exists.
# Ignoring reaction 'EX_sucr_e' since it already exists.
# Ignoring reaction 'EX_tartr__L_e' since it already exists.
# Ignoring reaction 'EX_thymd_e' since it already exists.
# Ignoring reaction 'EX_thym_e' since it already exists.
# Ignoring reaction 'EX_tre_e' since it already exists.
# Ignoring reaction 'EX_trp__L_e' since it already exists.
# Ignoring reaction 'EX_tsul_e' since it already exists.
# Ignoring reaction 'EX_udpgal_e' since it already exists.
# Ignoring reaction 'EX_2mbald_e' since it already exists.
# Ignoring reaction 'EX_3c3hmp_e' since it already exists.
# Ignoring reaction 'EX_akg_e' since it already exists.
# Ignoring reaction 'EX_arab__D_e' since it already exists.
# Ignoring reaction 'EX_btd_RR_e' since it already exists.
# Ignoring reaction 'EX_csn_e' since it already exists.
# Ignoring reaction 'EX_dttp_e' since it already exists.
# Ignoring reaction 'EX_h2o_e' since it already exists.
# Ignoring reaction 'EX_hexc_e' since it already exists.
# Ignoring reaction 'EX_ocdca_e' since it already exists.
# Ignoring reaction 'EX_2hb_e' since it already exists.
# Ignoring reaction 'EX_3mop_e' since it already exists.
# Ignoring reaction 'EX_4abz_e' since it already exists.
# Ignoring reaction 'EX_8aonn_e' since it already exists.
# Ignoring reaction 'EX_amet_e' since it already exists.
# Ignoring reaction 'EX_glx_e' since it already exists.
# Ignoring reaction 'EX_id3acald_e' since it already exists.
# Ignoring reaction 'EX_oaa_e' since it already exists.
# Ignoring reaction 'EX_sprm_e' since it already exists.
# Ignoring reaction 'EX_zymst_e' since it already exists.
# Ignoring reaction 'EX_gcald_e' since it already exists.
# Ignoring reaction 'EX_glc__D_e' since it already exists.
# Ignoring reaction 'EX_gly_e' since it already exists.
# Ignoring reaction 'EX_malt_e' since it already exists.
# Ignoring reaction 'EX_man_e' since it already exists.
# Ignoring reaction 'EX_o2_e' since it already exists.
# Ignoring reaction 'EX_srb__L_e' since it already exists.
# Ignoring reaction 'EX_fru_e' since it already exists.
# Ignoring reaction 'EX_ura_e' since it already exists.
# Ignoring reaction 'EX_acnam_e' since it already exists.
# Ignoring reaction 'EX_ala__L_e' since it already exists.
# Ignoring reaction 'EX_chol_e' since it already exists.
# Ignoring reaction 'EX_cobalt2_e' since it already exists.
# Ignoring reaction 'EX_ala__D_e' since it already exists.
# Ignoring reaction 'EX_ncam_e' since it already exists.
# Ignoring reaction 'EX_salcn_e' since it already exists.
# Ignoring reaction 'EX_glcn_e' since it already exists.
# Ignoring reaction 'EX_leu__L_e' since it already exists.
# Ignoring reaction 'EX_nh4_e' since it already exists.
# Ignoring reaction 'EX_drib_e' since it already exists.
# Ignoring reaction 'EX_4hphac_e' since it already exists.
# Ignoring reaction 'EX_tcb_e' since it already exists.
# Ignoring reaction 'EX_tton_e' since it already exists.
# Ignoring reaction 'EX_salchs4fe_e' since it already exists.
# Ignoring reaction 'EX_tag__D_e' since it already exists.
# Ignoring reaction 'EX_3pg_e' since it already exists.
# Ignoring reaction 'EX_frmd_e' since it already exists.
# Ignoring reaction 'EX_13ppd_e' since it already exists.
# Ignoring reaction 'EX_cellb_e' since it already exists.
# Ignoring reaction 'EX_bz_e' since it already exists.
# Ignoring reaction 'EX_abt__D_e' since it already exists.
# Ignoring reaction 'EX_peng_e' since it already exists.
# Ignoring reaction 'EX_6apa_e' since it already exists.
# Ignoring reaction 'EX_pac_e' since it already exists.
# Ignoring reaction 'EX_2dhglcn_e' since it already exists.
# Ignoring reaction 'EX_4hbz_e' since it already exists.
# Ignoring reaction 'EX_chols_e' since it already exists.
# Ignoring reaction 'EX_34dhcinm_e' since it already exists.
# Ignoring reaction 'EX_m_xyl_e' since it already exists.
# Ignoring reaction 'EX_p_xyl_e' since it already exists.
# Ignoring reaction 'EX_tol_e' since it already exists.
# Ignoring reaction 'EX_hco3_e' since it already exists.
# Ignoring reaction 'EX_T4hcinnm_e' since it already exists.
# Ignoring reaction 'EX_pime_e' since it already exists.
# Ignoring reaction 'EX_meoh_e' since it already exists.
# Ignoring reaction 'EX_malthp_e' since it already exists.
# Ignoring reaction 'EX_co_e' since it already exists.
# Ignoring reaction 'EX_coa_e' since it already exists.
# Ignoring reaction 'EX_fuc__L_e' since it already exists.
# Ignoring reaction 'EX_fum_e' since it already exists.
# Ignoring reaction 'EX_4abut_e' since it already exists.
# Ignoring reaction 'EX_diact_e' since it already exists.
# Ignoring reaction 'EX_Lcyst_e' since it already exists.
# Ignoring reaction 'EX_btoh_e' since it already exists.
# Ignoring reaction 'EX_bzal_e' since it already exists.
# Ignoring reaction 'EX_n2_e' since it already exists.
# Ignoring reaction 'EX_oxa_e' since it already exists.
# Ignoring reaction 'EX_ppoh_e' since it already exists.
# Ignoring reaction 'EX_pta_e' since it already exists.
# Ignoring reaction 'EX_4hba_e' since it already exists.
# Ignoring reaction 'EX_ibt_e' since it already exists.
# Ignoring reaction 'EX_25hvitd2_e' since it already exists.
# Ignoring reaction 'EX_2mcit_e' since it already exists.
# Ignoring reaction 'EX_34dhoxpeg_e' since it already exists.
# Ignoring reaction 'EX_3aib_e' since it already exists.
# Ignoring reaction 'EX_5homeprazole_e' since it already exists.
# Ignoring reaction 'EX_7dhf_e' since it already exists.
# Ignoring reaction 'EX_7thf_e' since it already exists.
# Ignoring reaction 'EX_clpnd_e' since it already exists.
# Ignoring reaction 'EX_ach_e' since it already exists.
# Ignoring reaction 'EX_adrn_e' since it already exists.
# Ignoring reaction 'EX_andrstrn_e' since it already exists.
# Ignoring reaction 'EX_apnnox_e' since it already exists.
# Ignoring reaction 'EX_arach_e' since it already exists.
# Ignoring reaction 'EX_asp__D_e' since it already exists.
# Ignoring reaction 'EX_avite1_e' since it already exists.
# Ignoring reaction 'EX_bhb_e' since it already exists.
# Ignoring reaction 'EX_bildglcur_e' since it already exists.
# Ignoring reaction 'EX_bilglcur_e' since it already exists.
# Ignoring reaction 'EX_bvite_e' since it already exists.
# Ignoring reaction 'EX_chtn_e' since it already exists.
# Ignoring reaction 'EX_dcsptn1_e' since it already exists.
# Ignoring reaction 'EX_dgchol_e' since it already exists.
# Ignoring reaction 'EX_dheas_e' since it already exists.
# Ignoring reaction 'EX_elaid_e' since it already exists.
# Ignoring reaction 'EX_gchola_e' since it already exists.
# Ignoring reaction 'EX_glygn4_e' since it already exists.
# Ignoring reaction 'EX_glygn5_e' since it already exists.
# Ignoring reaction 'EX_hcoumarin_e' since it already exists.
# Ignoring reaction 'EX_leuktrA4_e' since it already exists.
# Ignoring reaction 'EX_leuktrD4_e' since it already exists.
# Ignoring reaction 'EX_leuktrF4_e' since it already exists.
# Ignoring reaction 'EX_lgnc_e' since it already exists.
# Ignoring reaction 'EX_lneldc_e' since it already exists.
# Ignoring reaction 'EX_lnlc_e' since it already exists.
# Ignoring reaction 'EX_lnlnca_e' since it already exists.
# Ignoring reaction 'EX_nrvnc_e' since it already exists.
# Ignoring reaction 'EX_pe_hs_e' since it already exists.
# Ignoring reaction 'EX_pro__D_e' since it already exists.
# Ignoring reaction 'EX_ps_hs_e' since it already exists.
# Ignoring reaction 'EX_retn_e' since it already exists.
# Ignoring reaction 'EX_sl__L_e' since it already exists.
# Ignoring reaction 'EX_sphs1p_e' since it already exists.
# Ignoring reaction 'EX_srtn_e' since it already exists.
# Ignoring reaction 'EX_strch2_e' since it already exists.
# Ignoring reaction 'EX_tchola_e' since it already exists.
# Ignoring reaction 'EX_tethex3_e' since it already exists.
# Ignoring reaction 'EX_thf_e' since it already exists.
# Ignoring reaction 'EX_tmndnc_e' since it already exists.
# Ignoring reaction 'EX_tststerone_e' since it already exists.
# Ignoring reaction 'EX_udp_e' since it already exists.
# Ignoring reaction 'EX_vitd3_e' since it already exists.
# Ignoring reaction 'EX_25hvitd3_e' since it already exists.
# Ignoring reaction 'EX_4nph_e' since it already exists.
# Ignoring reaction 'EX_5mthf_e' since it already exists.
# Ignoring reaction 'EX_arachd_e' since it already exists.
# Ignoring reaction 'EX_caro_e' since it already exists.
# Ignoring reaction 'EX_cholate_e' since it already exists.
# Ignoring reaction 'EX_coumarin_e' since it already exists.
# Ignoring reaction 'EX_crvnc_e' since it already exists.
# Ignoring reaction 'EX_dhdascb_e' since it already exists.
# Ignoring reaction 'EX_dlnlcg_e' since it already exists.
# Ignoring reaction 'EX_dopa_e' since it already exists.
# Ignoring reaction 'EX_estradiol_e' since it already exists.
# Ignoring reaction 'EX_estrones_e' since it already exists.
# Ignoring reaction 'EX_fol_e' since it already exists.
# Ignoring reaction 'EX_10fthf7glu_e' since it already exists.
# Ignoring reaction 'EX_10fthf6glu_e' since it already exists.
# Ignoring reaction 'EX_6dhf_e' since it already exists.
# Ignoring reaction 'EX_hista_e' since it already exists.
# Ignoring reaction 'EX_hpdca_e' since it already exists.
# Ignoring reaction 'EX_chsterol_e' since it already exists.
# Ignoring reaction 'EX_pchol_hs_e' since it already exists.
# Ignoring reaction 'EX_xolest2_hs_e' since it already exists.
# Ignoring reaction 'EX_lnlncg_e' since it already exists.
# Ignoring reaction 'EX_Rtotal2_e' since it already exists.
# Ignoring reaction 'EX_Rtotal3_e' since it already exists.
# Ignoring reaction 'EX_nadp_e' since it already exists.
# Ignoring reaction 'EX_i_e' since it already exists.
# Ignoring reaction 'EX_utp_e' since it already exists.
# Ignoring reaction 'EX_nrpphr_e' since it already exists.
# Ignoring reaction 'EX_octa_e' since it already exists.
# Ignoring reaction 'EX_paf_hs_e' since it already exists.
# Ignoring reaction 'EX_ak2lgchol_hs_e' since it already exists.
# Ignoring reaction 'EX_phe__L_e' since it already exists.
# Ignoring reaction 'EX_prgstrn_e' since it already exists.
# Ignoring reaction 'EX_prostge1_e' since it already exists.
# Ignoring reaction 'EX_prostge2_e' since it already exists.
# Ignoring reaction 'EX_prostgi2_e' since it already exists.
# Ignoring reaction 'EX_ribflv_e' since it already exists.
# Ignoring reaction 'EX_o2s_e' since it already exists.
# Ignoring reaction 'EX_strdnc_e' since it already exists.
# Ignoring reaction 'EX_tcynt_e' since it already exists.
# Ignoring reaction 'EX_tetpent6_e' since it already exists.
# Ignoring reaction 'EX_thyox__L_e' since it already exists.
# Ignoring reaction 'EX_triodthy_e' since it already exists.
# Ignoring reaction 'EX_vacc_e' since it already exists.
# Ignoring reaction 'EX_alac__S_e' since it already exists.
# Ignoring reaction 'EX_ch4s_e' since it already exists.
# Ignoring reaction 'EX_s_e' since it already exists.
# Ignoring reaction 'EX_ind3ac_e' since it already exists.
# Ignoring reaction 'EX_mma_e' since it already exists.
# Ignoring reaction 'EX_cell6_e' since it already exists.
# Ignoring reaction 'EX_galman6_e' since it already exists.
# Ignoring reaction 'EX_manb_e' since it already exists.
# Ignoring reaction 'EX_manttr_e' since it already exists.
# Ignoring reaction 'EX_galman4_e' since it already exists.
# Ignoring reaction 'EX_glcman4_e' since it already exists.
# Ignoring reaction 'EX_glcman6_e' since it already exists.
# Ignoring reaction 'EX_glucan6_e' since it already exists.
# Ignoring reaction 'EX_glucan4_e' since it already exists.
# Ignoring reaction 'EX_xylb_e' since it already exists.
# Ignoring reaction 'EX_araban__L_e' since it already exists.
# Ignoring reaction 'EX_udcpp_e' since it already exists.
# Ignoring reaction 'EX_citr__L_e' since it already exists.
# Ignoring reaction 'EX_udcpdp_e' since it already exists.
# Ignoring reaction 'EX_2pg_e' since it already exists.
# Ignoring reaction 'EX_actn__R_e' since it already exists.
# Ignoring reaction 'EX_madg_e' since it already exists.
# Ignoring reaction 'EX_ctbt_e' since it already exists.
# Ignoring reaction 'EX_dextrin_e' since it already exists.
# Ignoring reaction 'EX_met_L_ala__L_e' since it already exists.
# Ignoring reaction 'EX_gly_pro__L_e' since it already exists.
# Ignoring reaction 'EX_eths_e' since it already exists.
# Ignoring reaction 'EX_2pglyc_e' since it already exists.
# Ignoring reaction 'EX_6pgc_e' since it already exists.
# Ignoring reaction 'EX_Larab_e' since it already exists.
# Ignoring reaction 'EX_ala_L_glu__L_e' since it already exists.
# Ignoring reaction 'EX_argp_e' since it already exists.
# Ignoring reaction 'EX_buts_e' since it already exists.
# Ignoring reaction 'EX_chor_e' since it already exists.
# Ignoring reaction 'EX_cyst__L_e' since it already exists.
# Ignoring reaction 'EX_glcn__D_e' since it already exists.
# Ignoring reaction 'EX_gly_asp__L_e' since it already exists.
# Ignoring reaction 'EX_hexs_e' since it already exists.
# Ignoring reaction 'EX_istnt_e' since it already exists.
# Ignoring reaction 'EX_orn__L_e' since it already exists.
# Ignoring reaction 'EX_ppi_e' since it already exists.
# Ignoring reaction 'EX_starch_e' since it already exists.
# Ignoring reaction 'EX_f6p_e' since it already exists.
# Ignoring reaction 'EX_g1p_e' since it already exists.
# Ignoring reaction 'EX_galctr__D_e' since it already exists.
# Ignoring reaction 'EX_glu__D_e' since it already exists.
# Ignoring reaction 'EX_icit_e' since it already exists.
# Ignoring reaction 'EX_mal__D_e' since it already exists.
# Ignoring reaction 'EX_34dhphe_e' since it already exists.
# Ignoring reaction 'EX_hcys__L_e' since it already exists.
# Ignoring reaction 'EX_thmmp_e' since it already exists.
# Ignoring reaction 'EX_3mob_e' since it already exists.
# Ignoring reaction 'EX_4hpro_LT_e' since it already exists.
# Ignoring reaction 'EX_aicar_e' since it already exists.
# Ignoring reaction 'EX_ak2lgchol_cho_e' since it already exists.
# Ignoring reaction 'EX_anth_e' since it already exists.
# Ignoring reaction 'EX_c10dc_e' since it already exists.
# Ignoring reaction 'EX_c4crn_e' since it already exists.
# Ignoring reaction 'EX_c6dc_e' since it already exists.
# Ignoring reaction 'EX_4abutn_e' since it already exists.
# Ignoring reaction 'EX_5mta_e' since it already exists.
# Ignoring reaction 'EX_5oxpro_e' since it already exists.
# Ignoring reaction 'EX_12HPET_e' since it already exists.
# Ignoring reaction 'EX_CE0074_e' since it already exists.
# Ignoring reaction 'EX_CE1926_e' since it already exists.
# Ignoring reaction 'EX_CE2011_e' since it already exists.
# Ignoring reaction 'EX_CE2250_e' since it already exists.
# Ignoring reaction 'EX_CE2838_e' since it already exists.
# Ignoring reaction 'EX_CE4633_e' since it already exists.
# Ignoring reaction 'EX_CE4723_e' since it already exists.
# Ignoring reaction 'EX_CE5788_e' since it already exists.
# Ignoring reaction 'EX_CE5789_e' since it already exists.
# Ignoring reaction 'EX_CE5797_e' since it already exists.
# Ignoring reaction 'EX_CE5867_e' since it already exists.
# Ignoring reaction 'EX_CE5869_e' since it already exists.
# Ignoring reaction 'EX_HC00229_e' since it already exists.
# Ignoring reaction 'EX_HC00250_e' since it already exists.
# Ignoring reaction 'EX_HC00822_e' since it already exists.
# Ignoring reaction 'EX_HC01440_e' since it already exists.
# Ignoring reaction 'EX_HC01441_e' since it already exists.
# Ignoring reaction 'EX_HC01577_e' since it already exists.
# Ignoring reaction 'EX_cpppg1_e' since it already exists.
# Ignoring reaction 'EX_wharachd_e' since it already exists.
# Ignoring reaction 'EX_HC02187_e' since it already exists.
# Ignoring reaction 'EX_HC02191_e' since it already exists.
# Ignoring reaction 'EX_HC02192_e' since it already exists.
# Ignoring reaction 'EX_HC02194_e' since it already exists.
# Ignoring reaction 'EX_HC02195_e' since it already exists.
# Ignoring reaction 'EX_HC02196_e' since it already exists.
# Ignoring reaction 'EX_HC02197_e' since it already exists.
# Ignoring reaction 'EX_HC02203_e' since it already exists.
# Ignoring reaction 'EX_HC02204_e' since it already exists.
# Ignoring reaction 'EX_HC02207_e' since it already exists.
# Ignoring reaction 'EX_HC02220_e' since it already exists.
# Ignoring reaction 'EX_ahcys_e' since it already exists.
# Ignoring reaction 'EX_c8crn_e' since it already exists.
# Ignoring reaction 'EX_c8dc_e' since it already exists.
# Ignoring reaction 'EX_carn_e' since it already exists.
# Ignoring reaction 'EX_cdp_e' since it already exists.
# Ignoring reaction 'EX_ctp_e' since it already exists.
# Ignoring reaction 'EX_dgtp_e' since it already exists.
# Ignoring reaction 'EX_dtdp_e' since it already exists.
# Ignoring reaction 'EX_glyleu_e' since it already exists.
# Ignoring reaction 'EX_glyphe_e' since it already exists.
# Ignoring reaction 'EX_glysar_e' since it already exists.
# Ignoring reaction 'EX_leugly_e' since it already exists.
# Ignoring reaction 'EX_leuleu_e' since it already exists.
# Ignoring reaction 'EX_lpchol_cho_e' since it already exists.
# Ignoring reaction 'EX_malcoa_e' since it already exists.
# Ignoring reaction 'EX_paf_cho_e' since it already exists.
# Ignoring reaction 'EX_prostgh2_e' since it already exists.
# Ignoring reaction 'EX_prpp_e' since it already exists.
# Ignoring reaction 'EX_ptth_e' since it already exists.
# Ignoring reaction 'EX_pydx5p_e' since it already exists.
# Ignoring reaction 'EX_q10_e' since it already exists.
# Ignoring reaction 'EX_slfcys_e' since it already exists.
# Ignoring reaction 'EX_tag_cho_e' since it already exists.
# Ignoring reaction 'EX_hyptaur_e' since it already exists.
# Ignoring reaction 'EX_dag_cho_e' since it already exists.
# Ignoring reaction 'EX_mag_cho_e' since it already exists.
# Ignoring reaction 'EX_pe_cho_e' since it already exists.
# Ignoring reaction 'EX_pan4p_e' since it already exists.
# Ignoring reaction 'EX_arachcoa_e' since it already exists.
# Ignoring reaction 'EX_CE2915_e' since it already exists.
# Ignoring reaction 'EX_CE4722_e' since it already exists.
# Ignoring reaction 'EX_CE2916_e' since it already exists.
# Ignoring reaction 'EX_23cump_e' since it already exists.
# Ignoring reaction 'EX_CE5798_e' since it already exists.
# Ignoring reaction 'EX_urate_e' since it already exists.
# Ignoring reaction 'EX_cholp_e' since it already exists.
# Ignoring reaction 'EX_ump_e' since it already exists.
# Ignoring reaction 'EX_HC00955_e' since it already exists.
# Ignoring reaction 'EX_HC01361_e' since it already exists.
# Ignoring reaction 'EX_ahdt_e' since it already exists.
# Ignoring reaction 'EX_fad_e' since it already exists.
# Ignoring reaction 'EX_creat_e' since it already exists.
# Ignoring reaction 'EX_C02528_e' since it already exists.
# Ignoring reaction 'EX_HC02193_e' since it already exists.
# Ignoring reaction 'EX_bilirub_e' since it already exists.
# Ignoring reaction 'EX_hom__L_e' since it already exists.
# Ignoring reaction 'EX_HC02198_e' since it already exists.
# Ignoring reaction 'EX_tdchola_e' since it already exists.
# Ignoring reaction 'EX_leuktrE4_e' since it already exists.
# Ignoring reaction 'EX_leuktrC4_e' since it already exists.
# Ignoring reaction 'EX_HC02180_e' since it already exists.
# Ignoring reaction 'EX_leuktrB4_e' since it already exists.
# Ignoring reaction 'EX_HC02202_e' since it already exists.
# Ignoring reaction 'EX_HC02205_e' since it already exists.
# Ignoring reaction 'EX_prostgd2_e' since it already exists.
# Ignoring reaction 'EX_HC02213_e' since it already exists.
# Ignoring reaction 'EX_prostgf2_e' since it already exists.
# Ignoring reaction 'EX_HC02217_e' since it already exists.
# Ignoring reaction 'EX_HC02206_e' since it already exists.
# Ignoring reaction 'EX_2mba_e' since it already exists.
# Ignoring reaction 'EX_pea_e' since it already exists.
# Ignoring reaction 'EX_dxylnt_e' since it already exists.
# Ignoring reaction 'EX_4abzglu_e' since it already exists.
# Ignoring reaction 'EX_metglcur_e' since it already exists.
# Ignoring reaction 'EX_5fthf_e' since it already exists.
# Ignoring reaction 'EX_isomal_e' since it already exists.
# Ignoring reaction 'EX_HC01700_e' since it already exists.
# Ignoring reaction 'EX_galside_hs_e' since it already exists.
# Ignoring reaction 'EX_crm_hs_e' since it already exists.
# Ignoring reaction 'EX_CE5787_e' since it already exists.
# Ignoring reaction 'EX_CE5791_e' since it already exists.
# Ignoring reaction 'EX_Lkynr_e' since it already exists.
# Ignoring reaction 'EX_cala_e' since it already exists.
# Ignoring reaction 'EX_hLkynr_e' since it already exists.
# Ignoring reaction 'EX_quln_e' since it already exists.
# Ignoring reaction 'EX_dhap_e' since it already exists.
# Ignoring reaction 'EX_udpglcur_e' since it already exists.
# Ignoring reaction 'EX_dmgly_e' since it already exists.
# Ignoring reaction 'EX_ethamp_e' since it already exists.
# Ignoring reaction 'EX_estradiolglc_e' since it already exists.
# Ignoring reaction 'EX_pglyc_hs_e' since it already exists.
# Ignoring reaction 'EX_argsuc_e' since it already exists.
# Ignoring reaction 'EX_acrn_e' since it already exists.
# Ignoring reaction 'EX_pelinl_hs_e' since it already exists.
# Ignoring reaction 'EX_biliverd_e' since it already exists.
# Ignoring reaction 'EX_CE2176_e' since it already exists.
# Ignoring reaction 'EX_CE7082_e' since it already exists.
# Ignoring reaction 'EX_CE7172_e' since it already exists.
# Ignoring reaction 'EX_cortsn_e' since it already exists.
# Ignoring reaction 'EX_forglu_e' since it already exists.
# Ignoring reaction 'EX_xolest182_hs_e' since it already exists.
# Ignoring reaction 'EX_xolest183_hs_e' since it already exists.
# Ignoring reaction 'EX_xolest226_hs_e' since it already exists.
# Ignoring reaction 'EX_Lpipecol_e' since it already exists.
# Ignoring reaction 'EX_ttdcea_e' since it already exists.
# Ignoring reaction 'EX_acglu_e' since it already exists.
# Ignoring reaction 'EX_CE2510_e' since it already exists.
# Ignoring reaction 'EX_pheacgly_e' since it already exists.
# Ignoring reaction 'EX_alaargcys_e' since it already exists.
# Ignoring reaction 'EX_alaarggly_e' since it already exists.
# Ignoring reaction 'EX_alaasnleu_e' since it already exists.
# Ignoring reaction 'EX_alahisala_e' since it already exists.
# Ignoring reaction 'EX_alalysthr_e' since it already exists.
# Ignoring reaction 'EX_argalathr_e' since it already exists.
# Ignoring reaction 'EX_argarglys_e' since it already exists.
# Ignoring reaction 'EX_argargmet_e' since it already exists.
# Ignoring reaction 'EX_argcysser_e' since it already exists.
# Ignoring reaction 'EX_arggluglu_e' since it already exists.
# Ignoring reaction 'EX_argglupro_e' since it already exists.
# Ignoring reaction 'EX_arghisthr_e' since it already exists.
# Ignoring reaction 'EX_argpromet_e' since it already exists.
# Ignoring reaction 'EX_argprothr_e' since it already exists.
# Ignoring reaction 'EX_argtyrval_e' since it already exists.
# Ignoring reaction 'EX_asncyscys_e' since it already exists.
# Ignoring reaction 'EX_asnmetpro_e' since it already exists.
# Ignoring reaction 'EX_asnpheasp_e' since it already exists.
# Ignoring reaction 'EX_asntyrphe_e' since it already exists.
# Ignoring reaction 'EX_aspasnglu_e' since it already exists.
# Ignoring reaction 'EX_aspglutrp_e' since it already exists.
# Ignoring reaction 'EX_asphispro_e' since it already exists.
# Ignoring reaction 'EX_asplyshis_e' since it already exists.
# Ignoring reaction 'EX_aspprolys_e' since it already exists.
# Ignoring reaction 'EX_cysaspphe_e' since it already exists.
# Ignoring reaction 'EX_cyscys_e' since it already exists.
# Ignoring reaction 'EX_cysleuthr_e' since it already exists.
# Ignoring reaction 'EX_cystyrasn_e' since it already exists.
# Ignoring reaction 'EX_glnhishis_e' since it already exists.
# Ignoring reaction 'EX_glnhislys_e' since it already exists.
# Ignoring reaction 'EX_glnlyslys_e' since it already exists.
# Ignoring reaction 'EX_glnlystrp_e' since it already exists.
# Ignoring reaction 'EX_glnproglu_e' since it already exists.
# Ignoring reaction 'EX_gluargleu_e' since it already exists.
# Ignoring reaction 'EX_gluthr_e' since it already exists.
# Ignoring reaction 'EX_gluthrlys_e' since it already exists.
# Ignoring reaction 'EX_glutrpala_e' since it already exists.
# Ignoring reaction 'EX_glytyrlys_e' since it already exists.
# Ignoring reaction 'EX_glyvalhis_e' since it already exists.
# Ignoring reaction 'EX_hisargcys_e' since it already exists.
# Ignoring reaction 'EX_hiscyscys_e' since it already exists.
# Ignoring reaction 'EX_hishislys_e' since it already exists.
# Ignoring reaction 'EX_hislysala_e' since it already exists.
# Ignoring reaction 'EX_hislysthr_e' since it already exists.
# Ignoring reaction 'EX_hismet_e' since it already exists.
# Ignoring reaction 'EX_hisphearg_e' since it already exists.
# Ignoring reaction 'EX_hisprolys_e' since it already exists.
# Ignoring reaction 'EX_histrphis_e' since it already exists.
# Ignoring reaction 'EX_ileasnhis_e' since it already exists.
# Ignoring reaction 'EX_ileasp_e' since it already exists.
# Ignoring reaction 'EX_ileprolys_e' since it already exists.
# Ignoring reaction 'EX_leuasplys_e' since it already exists.
# Ignoring reaction 'EX_leuleutrp_e' since it already exists.
# Ignoring reaction 'EX_leupro_e' since it already exists.
# Ignoring reaction 'EX_leusertrp_e' since it already exists.
# Ignoring reaction 'EX_leutrp_e' since it already exists.
# Ignoring reaction 'EX_leutrparg_e' since it already exists.
# Ignoring reaction 'EX_leuval_e' since it already exists.
# Ignoring reaction 'EX_lysglnphe_e' since it already exists.
# Ignoring reaction 'EX_lyslyslys_e' since it already exists.
# Ignoring reaction 'EX_lyspheile_e' since it already exists.
# Ignoring reaction 'EX_lysvalphe_e' since it already exists.
# Ignoring reaction 'EX_metglyarg_e' since it already exists.
# Ignoring reaction 'EX_metmetile_e' since it already exists.
# Ignoring reaction 'EX_mettrpphe_e' since it already exists.
# Ignoring reaction 'EX_pheasnmet_e' since it already exists.
# Ignoring reaction 'EX_pheasp_e' since it already exists.
# Ignoring reaction 'EX_pheleuasp_e' since it already exists.
# Ignoring reaction 'EX_phelysala_e' since it already exists.
# Ignoring reaction 'EX_phephe_e' since it already exists.
# Ignoring reaction 'EX_phephethr_e' since it already exists.
# Ignoring reaction 'EX_phethrlys_e' since it already exists.
# Ignoring reaction 'EX_phetrpleu_e' since it already exists.
# Ignoring reaction 'EX_phetyrgln_e' since it already exists.
# Ignoring reaction 'EX_prohistyr_e' since it already exists.
# Ignoring reaction 'EX_proleuarg_e' since it already exists.
# Ignoring reaction 'EX_proproarg_e' since it already exists.
# Ignoring reaction 'EX_protrplys_e' since it already exists.
# Ignoring reaction 'EX_protrpthr_e' since it already exists.
# Ignoring reaction 'EX_serargala_e' since it already exists.
# Ignoring reaction 'EX_sercysarg_e' since it already exists.
# Ignoring reaction 'EX_sertrphis_e' since it already exists.
# Ignoring reaction 'EX_thrasntyr_e' since it already exists.
# Ignoring reaction 'EX_thrilearg_e' since it already exists.
# Ignoring reaction 'EX_thrmetarg_e' since it already exists.
# Ignoring reaction 'EX_thrphearg_e' since it already exists.
# Ignoring reaction 'EX_thrserarg_e' since it already exists.
# Ignoring reaction 'EX_thrthrarg_e' since it already exists.
# Ignoring reaction 'EX_trpalapro_e' since it already exists.
# Ignoring reaction 'EX_trpargala_e' since it already exists.
# Ignoring reaction 'EX_trpaspasp_e' since it already exists.
# Ignoring reaction 'EX_trpglutyr_e' since it already exists.
# Ignoring reaction 'EX_trpiletrp_e' since it already exists.
# Ignoring reaction 'EX_trplys_e' since it already exists.
# Ignoring reaction 'EX_trpmetval_e' since it already exists.
# Ignoring reaction 'EX_trpproleu_e' since it already exists.
# Ignoring reaction 'EX_trpsertyr_e' since it already exists.
# Ignoring reaction 'EX_trpthrile_e' since it already exists.
# Ignoring reaction 'EX_trpthrtyr_e' since it already exists.
# Ignoring reaction 'EX_trptyrgln_e' since it already exists.
# Ignoring reaction 'EX_tyralaphe_e' since it already exists.
# Ignoring reaction 'EX_tyrargser_e' since it already exists.
# Ignoring reaction 'EX_tyrglu_e' since it already exists.
# Ignoring reaction 'EX_tyrtyr_e' since it already exists.
# Ignoring reaction 'EX_tyrvalmet_e' since it already exists.
# Ignoring reaction 'EX_valarggly_e' since it already exists.
# Ignoring reaction 'EX_vallystyr_e' since it already exists.
# Ignoring reaction 'EX_valtrpphe_e' since it already exists.
# Ignoring reaction 'EX_valval_e' since it already exists.
# Ignoring reaction 'EX_argalaphe_e' since it already exists.
# Ignoring reaction 'EX_argcysgly_e' since it already exists.
# Ignoring reaction 'EX_argleuphe_e' since it already exists.
# Ignoring reaction 'EX_arglysasp_e' since it already exists.
# Ignoring reaction 'EX_argserser_e' since it already exists.
# Ignoring reaction 'EX_argvalcys_e' since it already exists.
# Ignoring reaction 'EX_asnasnarg_e' since it already exists.
# Ignoring reaction 'EX_asntyrgly_e' since it already exists.
# Ignoring reaction 'EX_asntyrthr_e' since it already exists.
# Ignoring reaction 'EX_aspalaarg_e' since it already exists.
# Ignoring reaction 'EX_aspglu_e' since it already exists.
# Ignoring reaction 'EX_aspglupro_e' since it already exists.
# Ignoring reaction 'EX_asplysglu_e' since it already exists.
# Ignoring reaction 'EX_aspmetasp_e' since it already exists.
# Ignoring reaction 'EX_cysasnmet_e' since it already exists.
# Ignoring reaction 'EX_cysglnmet_e' since it already exists.
# Ignoring reaction 'EX_cyssermet_e' since it already exists.
# Ignoring reaction 'EX_glnasngln_e' since it already exists.
# Ignoring reaction 'EX_glntyrleu_e' since it already exists.
# Ignoring reaction 'EX_gluasnleu_e' since it already exists.
# Ignoring reaction 'EX_gluleu_e' since it already exists.
# Ignoring reaction 'EX_glyhisasn_e' since it already exists.
# Ignoring reaction 'EX_glylyscys_e' since it already exists.
# Ignoring reaction 'EX_glylysphe_e' since it already exists.
# Ignoring reaction 'EX_hisargser_e' since it already exists.
# Ignoring reaction 'EX_hisasp_e' since it already exists.
# Ignoring reaction 'EX_hislysglu_e' since it already exists.
# Ignoring reaction 'EX_hislysile_e' since it already exists.
# Ignoring reaction 'EX_hislysval_e' since it already exists.
# Ignoring reaction 'EX_hismetgln_e' since it already exists.
# Ignoring reaction 'EX_ileglnglu_e' since it already exists.
# Ignoring reaction 'EX_leualaarg_e' since it already exists.
# Ignoring reaction 'EX_leuproarg_e' since it already exists.
# Ignoring reaction 'EX_lysargleu_e' since it already exists.
# Ignoring reaction 'EX_lyscyshis_e' since it already exists.
# Ignoring reaction 'EX_lystrparg_e' since it already exists.
# Ignoring reaction 'EX_metasntyr_e' since it already exists.
# Ignoring reaction 'EX_methislys_e' since it already exists.
# Ignoring reaction 'EX_metphearg_e' since it already exists.
# Ignoring reaction 'EX_pheleu_e' since it already exists.
# Ignoring reaction 'EX_phelyspro_e' since it already exists.
# Ignoring reaction 'EX_phepheasn_e' since it already exists.
# Ignoring reaction 'EX_phetyr_e' since it already exists.
# Ignoring reaction 'EX_procys_e' since it already exists.
# Ignoring reaction 'EX_proglnpro_e' since it already exists.
# Ignoring reaction 'EX_proglulys_e' since it already exists.
# Ignoring reaction 'EX_prohis_e' since it already exists.
# Ignoring reaction 'EX_prophe_e' since it already exists.
# Ignoring reaction 'EX_propropro_e' since it already exists.
# Ignoring reaction 'EX_serargtrp_e' since it already exists.
# Ignoring reaction 'EX_serglyglu_e' since it already exists.
# Ignoring reaction 'EX_serlyshis_e' since it already exists.
# Ignoring reaction 'EX_thrglnglu_e' since it already exists.
# Ignoring reaction 'EX_thrglntyr_e' since it already exists.
# Ignoring reaction 'EX_trpglngln_e' since it already exists.
# Ignoring reaction 'EX_trpgluleu_e' since it already exists.
# Ignoring reaction 'EX_trpglupro_e' since it already exists.
# Ignoring reaction 'EX_trpglyval_e' since it already exists.
# Ignoring reaction 'EX_trphismet_e' since it already exists.
# Ignoring reaction 'EX_trpilelys_e' since it already exists.
# Ignoring reaction 'EX_trpleuval_e' since it already exists.
# Ignoring reaction 'EX_trpproval_e' since it already exists.
# Ignoring reaction 'EX_trptyrtyr_e' since it already exists.
# Ignoring reaction 'EX_trpvalasp_e' since it already exists.
# Ignoring reaction 'EX_tyrala_e' since it already exists.
# Ignoring reaction 'EX_tyrasparg_e' since it already exists.
# Ignoring reaction 'EX_tyrcysgly_e' since it already exists.
# Ignoring reaction 'EX_tyrcysthr_e' since it already exists.
# Ignoring reaction 'EX_tyrleuarg_e' since it already exists.
# Ignoring reaction 'EX_tyrthr_e' since it already exists.
# Ignoring reaction 'EX_tyrtrpphe_e' since it already exists.
# Ignoring reaction 'EX_valhisasn_e' since it already exists.
# Ignoring reaction 'EX_valleuphe_e' since it already exists.
# Ignoring reaction 'EX_valphearg_e' since it already exists.
# Ignoring reaction 'EX_valprotrp_e' since it already exists.
# Ignoring reaction 'EX_valtrpval_e' since it already exists.
# Ignoring reaction 'EX_xolest205_hs_e' since it already exists.
# Ignoring reaction 'EX_hdcecrn_e' since it already exists.
# Ignoring reaction 'EX_phpyr_e' since it already exists.
# Ignoring reaction 'EX_3mox4hoxm_e' since it already exists.
# Ignoring reaction 'EX_CE1243_e' since it already exists.
# Ignoring reaction 'EX_2obut_e' since it already exists.
# Ignoring reaction 'EX_mlthf_e' since it already exists.
# Ignoring reaction 'EX_CE2705_e' since it already exists.
# Ignoring reaction 'EX_hdd2crn_e' since it already exists.
# Ignoring reaction 'EX_34dhoxmand_e' since it already exists.
# Ignoring reaction 'EX_5g2oxpt_e' since it already exists.
# Ignoring reaction 'EX_xol25oh_e' since it already exists.
# Ignoring reaction 'EX_dsmsterol_e' since it already exists.
# Ignoring reaction 'EX_chsterols_e' since it already exists.
# Ignoring reaction 'EX_CE1617_e' since it already exists.
# Ignoring reaction 'EX_fna5moxam_e' since it already exists.
# Ignoring reaction 'EX_melatn_e' since it already exists.
# Ignoring reaction 'EX_6hoxmelatn_e' since it already exists.
# Ignoring reaction 'EX_xylu__D_e' since it already exists.
# Ignoring reaction 'EX_CE0737_e' since it already exists.
# Ignoring reaction 'EX_CE1918_e' since it already exists.
# Ignoring reaction 'EX_sphgn_e' since it already exists.
# Ignoring reaction 'EX_5a2opntn_e' since it already exists.
# Ignoring reaction 'EX_arg__D_e' since it already exists.
# Ignoring reaction 'EX_gd3_hs_e' since it already exists.
# Ignoring reaction 'EX_gm3_hs_e' since it already exists.
# Ignoring reaction 'EX_cmpacna_e' since it already exists.
# Ignoring reaction 'EX_docosac_e' since it already exists.
# Ignoring reaction 'EX_HC01446_e' since it already exists.
# Ignoring reaction 'EX_h2co3_e' since it already exists.
# Ignoring reaction 'EX_dcyt_e' since it already exists.
# Ignoring reaction 'EX_M02446_e' since it already exists.
# Ignoring reaction 'EX_rbl__D_e' since it already exists.
# Ignoring reaction 'EX_2hatvacid_e' since it already exists.
# Ignoring reaction 'EX_2hatvlac_e' since it already exists.
# Ignoring reaction 'EX_3hpvs_e' since it already exists.
# Ignoring reaction 'EX_4hatvacid_e' since it already exists.
# Ignoring reaction 'EX_4hatvlac_e' since it already exists.
# Ignoring reaction 'EX_allop_e' since it already exists.
# Ignoring reaction 'EX_acmp_e' since it already exists.
# Ignoring reaction 'EX_atvacid_e' since it already exists.
# Ignoring reaction 'EX_atvlac_e' since it already exists.
# Ignoring reaction 'EX_crvs_e' since it already exists.
# Ignoring reaction 'EX_crvsm23_e' since it already exists.
# Ignoring reaction 'EX_ibup__R_e' since it already exists.
# Ignoring reaction 'EX_ibup__S_e' since it already exists.
# Ignoring reaction 'EX_lstn_e' since it already exists.
# Ignoring reaction 'EX_nfdnpy_e' since it already exists.
# Ignoring reaction 'EX_tmdm1_e' since it already exists.
# Ignoring reaction 'EX_nfd_e' since it already exists.
# Ignoring reaction 'EX_oxyp_e' since it already exists.
# Ignoring reaction 'EX_pvs_e' since it already exists.
# Ignoring reaction 'EX_smv_e' since it already exists.
# Ignoring reaction 'EX_tmd_e' since it already exists.
# Ignoring reaction 'EX_1a25dhvitd2_e' since it already exists.
# Ignoring reaction 'EX_M02956_e' since it already exists.
# Ignoring reaction 'EX_M00234_e' since it already exists.
# Ignoring reaction 'EX_M01807_e' since it already exists.
# Ignoring reaction 'EX_M00503_e' since it already exists.
# Ignoring reaction 'EX_octscoa_e' since it already exists.
# Ignoring reaction 'EX_ala_gln_e' since it already exists.
# Ignoring reaction 'EX_ala_leu_e' since it already exists.
# Ignoring reaction 'EX_ala_L_thr__L_e' since it already exists.
# Ignoring reaction 'EX_istfrnA_e' since it already exists.
# Ignoring reaction 'EX_istfrnB_e' since it already exists.
# Ignoring reaction 'EX_gly_cys_e' since it already exists.
# Ignoring reaction 'EX_glyglygln_e' since it already exists.
# Ignoring reaction 'EX_gly_phe_e' since it already exists.
# Ignoring reaction 'EX_g3pg_e' since it already exists.
# Ignoring reaction 'EX_4ahmmp_e' since it already exists.
# Ignoring reaction 'EX_metsox_R__L_e' since it already exists.
# Ignoring reaction 'EX_tre6p_e' since it already exists.
# Ignoring reaction 'EX_mnl1p_e' since it already exists.
# Ignoring reaction 'EX_ppap_e' since it already exists.
# Ignoring reaction 'EX_tartr__D_e' since it already exists.
# Ignoring reaction 'EX_arbt6p_e' since it already exists.
# Ignoring reaction 'EX_g6p_B_e' since it already exists.
# Ignoring reaction 'EX_dhpt_e' since it already exists.
# Ignoring reaction 'EX_lgn_e' since it already exists.
# Ignoring reaction 'EX_b_D_glucose_e' since it already exists.
# Ignoring reaction 'EX_a_D_glucose_e' since it already exists.
# Ignoring reaction 'EX_nh3_e' since it already exists.
# Ignoring reaction 'EX_ppat_e' since it already exists.
# Ignoring reaction 'EX_glc__aD_e' since it already exists.
# Ignoring reaction 'EX_mevR_e' since it already exists.
# Ignoring reaction 'EX_ham_e' since it already exists.
# Ignoring reaction 'EX_2ameph_e' since it already exists.
# Ignoring reaction 'EX_d23hb_e' since it already exists.
# Ignoring reaction 'EX_tagur_e' since it already exists.
# Ignoring reaction 'EX_abg4_e' since it already exists.
# Ignoring reaction 'EX_man6pglyc_e' since it already exists.
# Ignoring reaction 'EX_tgt_e' since it already exists.
# Ignoring reaction 'EX_uaccg_e' since it already exists.
# Ignoring reaction 'EX_5aptn_e' since it already exists.
# Ignoring reaction 'EX_alathr_e' since it already exists.
# Ignoring reaction 'EX_balaleu_e' since it already exists.
# Ignoring reaction 'EX_balamd_e' since it already exists.
# ...
# Ignoring reaction 'EX_3hpvs_e' since it already exists.
# Ignoring reaction 'EX_4hatvacid_e' since it already exists.
# Ignoring reaction 'EX_4hatvlac_e' since it already exists.
# Ignoring reaction 'EX_allop_e' since it already exists.
# Ignoring reaction 'EX_acmp_e' since it already exists.
# Ignoring reaction 'EX_atvacid_e' since it already exists.
# Ignoring reaction 'EX_atvlac_e' since it already exists.
# Ignoring reaction 'EX_crvs_e' since it already exists.
# Ignoring reaction 'EX_crvsm23_e' since it already exists.
# Ignoring reaction 'EX_ibup__R_e' since it already exists.
# Ignoring reaction 'EX_ibup__S_e' since it already exists.
# Ignoring reaction 'EX_lstn_e' since it already exists.
# Ignoring reaction 'EX_nfdnpy_e' since it already exists.
# Ignoring reaction 'EX_tmdm1_e' since it already exists.
# Ignoring reaction 'EX_nfd_e' since it already exists.
# Ignoring reaction 'EX_oxyp_e' since it already exists.
# Ignoring reaction 'EX_pvs_e' since it already exists.
# Ignoring reaction 'EX_smv_e' since it already exists.
# Ignoring reaction 'EX_tmd_e' since it already exists.
# Ignoring reaction 'EX_1a25dhvitd2_e' since it already exists.
# Ignoring reaction 'EX_M02956_e' since it already exists.
# Ignoring reaction 'EX_M00234_e' since it already exists.
# Ignoring reaction 'EX_M01807_e' since it already exists.
# Ignoring reaction 'EX_M00503_e' since it already exists.
# Ignoring reaction 'EX_octscoa_e' since it already exists.
# Ignoring reaction 'EX_ala_gln_e' since it already exists.
# Ignoring reaction 'EX_ala_leu_e' since it already exists.
# Ignoring reaction 'EX_ala_L_thr__L_e' since it already exists.
# Ignoring reaction 'EX_istfrnA_e' since it already exists.
# Ignoring reaction 'EX_istfrnB_e' since it already exists.
# Ignoring reaction 'EX_gly_cys_e' since it already exists.
# Ignoring reaction 'EX_glyglygln_e' since it already exists.
# Ignoring reaction 'EX_gly_phe_e' since it already exists.
# Ignoring reaction 'EX_g3pg_e' since it already exists.
# Ignoring reaction 'EX_4ahmmp_e' since it already exists.
# Ignoring reaction 'EX_metsox_R__L_e' since it already exists.
# Ignoring reaction 'EX_tre6p_e' since it already exists.
# Ignoring reaction 'EX_mnl1p_e' since it already exists.
# Ignoring reaction 'EX_ppap_e' since it already exists.
# Ignoring reaction 'EX_tartr__D_e' since it already exists.
# Ignoring reaction 'EX_arbt6p_e' since it already exists.
# Ignoring reaction 'EX_g6p_B_e' since it already exists.
# Ignoring reaction 'EX_dhpt_e' since it already exists.
# Ignoring reaction 'EX_lgn_e' since it already exists.
# Ignoring reaction 'EX_b_D_glucose_e' since it already exists.
# Ignoring reaction 'EX_a_D_glucose_e' since it already exists.
# Ignoring reaction 'EX_nh3_e' since it already exists.
# Ignoring reaction 'EX_ppat_e' since it already exists.
# Ignoring reaction 'EX_glc__aD_e' since it already exists.
# Ignoring reaction 'EX_mevR_e' since it already exists.
# Ignoring reaction 'EX_ham_e' since it already exists.
# Ignoring reaction 'EX_2ameph_e' since it already exists.
# Ignoring reaction 'EX_d23hb_e' since it already exists.
# Ignoring reaction 'EX_tagur_e' since it already exists.
# Ignoring reaction 'EX_abg4_e' since it already exists.
# Ignoring reaction 'EX_man6pglyc_e' since it already exists.
# Ignoring reaction 'EX_tgt_e' since it already exists.
# Ignoring reaction 'EX_uaccg_e' since it already exists.
# Ignoring reaction 'EX_5aptn_e' since it already exists.
# Ignoring reaction 'EX_alathr_e' since it already exists.
# Ignoring reaction 'EX_balaleu_e' since it already exists.
# Ignoring reaction 'EX_balamd_e' since it already exists.
# Ignoring reaction 'EX_pyovd_kt_e' since it already exists.
# Ignoring reaction 'EX_crtn_e' since it already exists.
# Ignoring reaction 'EX_12dgr160_e' since it already exists.
# Ignoring reaction 'EX_12dgr180_e' since it already exists.
# Ignoring reaction 'EX_dag181d9_e' since it already exists.
# Ignoring reaction 'EX_dag182d9d12_e' since it already exists.
# Ignoring reaction 'EX_asn__D_e' since it already exists.
# Ignoring reaction 'EX_leu__D_e' since it already exists.
# Ignoring reaction 'EX_lys__D_e' since it already exists.
# Ignoring reaction 'EX_phe__D_e' since it already exists.
# Ignoring reaction 'EX_val__D_e' since it already exists.
# Ignoring reaction 'EX_4hpro_DC_e' since it already exists.
# Ignoring reaction 'EX_5mcsn_e' since it already exists.
# Ignoring reaction 'EX_6atha_e' since it already exists.
# Ignoring reaction 'EX_R_3hcmrs7e_e' since it already exists.
# Ignoring reaction 'EX_R_3hhpa_e' since it already exists.
# Ignoring reaction 'EX_R_3hhxa_e' since it already exists.
# Ignoring reaction 'EX_R_3hocta_e' since it already exists.
# Ignoring reaction 'EX_R_3hpba_e' since it already exists.
# Ignoring reaction 'EX_R_3hpdeca_e' since it already exists.
# Ignoring reaction 'EX_R_3hpocta_e' since it already exists.
# Ignoring reaction 'EX_alahis_e' since it already exists.
# Ignoring reaction 'EX_alaleu_e' since it already exists.
# Ignoring reaction 'EX_balaala_e' since it already exists.
# Ignoring reaction 'EX_glycol_e' since it already exists.
# Ignoring reaction 'EX_glyglu_e' since it already exists.
# Ignoring reaction 'EX_glymet_e' since it already exists.
# Ignoring reaction 'EX_glyser_e' since it already exists.
# Ignoring reaction 'EX_hisgly_e' since it already exists.
# Ignoring reaction 'EX_phehpa_e' since it already exists.
# Ignoring reaction 'EX_phept_e' since it already exists.
# Ignoring reaction 'EX_ptsla_e' since it already exists.
# Ignoring reaction 'EX_tag160_e' since it already exists.
# Ignoring reaction 'EX_tag180_e' since it already exists.
# Ignoring reaction 'EX_tag181d9_e' since it already exists.
# Ignoring reaction 'EX_tag182d9d12_e' since it already exists.
# Ignoring reaction 'EX_glygln_e' since it already exists.
# Ignoring reaction 'EX_hishis_e' since it already exists.
# Ignoring reaction 'EX_Ncbmpts_e' since it already exists.
# Ignoring reaction 'EX_phedca_e' since it already exists.
# Ignoring reaction 'EX_phenona_e' since it already exists.
# Ignoring reaction 'EX_R_3hdcaa_e' since it already exists.
# Ignoring reaction 'EX_R_3httdca_e' since it already exists.
# Ignoring reaction 'EX_R_3hnonaa_e' since it already exists.
# Ignoring reaction 'EX_R_3hphpa_e' since it already exists.
# Ignoring reaction 'EX_R_3hpnona_e' since it already exists.
# Ignoring reaction 'EX_R_3h6atha_e' since it already exists.
# Ignoring reaction 'EX_4hptn_e' since it already exists.
# Ignoring reaction 'EX_4oxptn_e' since it already exists.
# Ignoring reaction 'EX_12ppd__R_e' since it already exists.
# Ignoring reaction 'EX_23camp_e' since it already exists.
# Ignoring reaction 'EX_3cmp_e' since it already exists.
# Ignoring reaction 'EX_3hpppn_e' since it already exists.
# Ignoring reaction 'EX_acgam1p_e' since it already exists.
# Ignoring reaction 'EX_dimp_e' since it already exists.
# Ignoring reaction 'EX_glyc2p_e' since it already exists.
# Ignoring reaction 'EX_manglyc_e' since it already exists.
# Ignoring reaction 'EX_ppt_e' since it already exists.
# Ignoring reaction 'EX_13BDglcn_e' since it already exists.
# Ignoring reaction 'EX_abt_e' since it already exists.
# Ignoring reaction 'EX_dann_e' since it already exists.
# Ignoring reaction 'EX_lanost_e' since it already exists.
# Ignoring reaction 'EX_pap_e' since it already exists.
# Ignoring reaction 'EX_dxyl_e' since it already exists.
# Ignoring reaction 'EX_airs_e' since it already exists.
# Ignoring reaction 'EX_3oxoadp_e' since it already exists.
# Ignoring reaction 'EX_catechol_e' since it already exists.
# Ignoring reaction 'EX_phenol_e' since it already exists.
# Ignoring reaction 'EX_3aib__D_e' since it already exists.
# Ignoring reaction 'EX_6thf_e' since it already exists.
# Ignoring reaction 'EX_appnn_e' since it already exists.
# Ignoring reaction 'EX_biocyt_e' since it already exists.
# Ignoring reaction 'EX_crtsl_e' since it already exists.
# Ignoring reaction 'EX_eicostet_e' since it already exists.
# Ignoring reaction 'EX_mthgxl_e' since it already exists.
# Ignoring reaction 'EX_omeprazole_e' since it already exists.
# Ignoring reaction 'EX_sarcs_e' since it already exists.
# Ignoring reaction 'EX_spc_hs_e' since it already exists.
# Ignoring reaction 'EX_tetpent3_e' since it already exists.
# Ignoring reaction 'EX_tettet6_e' since it already exists.
# Ignoring reaction 'EX_unknown_cbl1deg_e' since it already exists.
# Ignoring reaction 'EX_lmn2_e' since it already exists.
# Ignoring reaction 'EX_mantr_e' since it already exists.
# Ignoring reaction 'EX_xyl3_e' since it already exists.
# Ignoring reaction 'EX_xylan4_e' since it already exists.
# Ignoring reaction 'EX_xylan8_e' since it already exists.
# Ignoring reaction 'EX_2hxmp_e' since it already exists.
# Ignoring reaction 'EX_abt__L_e' since it already exists.
# Ignoring reaction 'EX_mbdg_e' since it already exists.
# Ignoring reaction 'EX_ala_L_asp__L_e' since it already exists.
# Ignoring reaction 'EX_gly_glu__L_e' since it already exists.
# Ignoring reaction 'EX_gly_asn__L_e' since it already exists.
# Ignoring reaction 'EX_man1p_e' since it already exists.
# Ignoring reaction 'EX_metox__R_e' since it already exists.
# Ignoring reaction 'EX_metox_e' since it already exists.
# Ignoring reaction 'EX_pala_e' since it already exists.
# Ignoring reaction 'EX_sula_e' since it already exists.
# Ignoring reaction 'EX_34hpp_e' since it already exists.
# Ignoring reaction 'EX_4mop_e' since it already exists.
# Ignoring reaction 'EX_c4dc_e' since it already exists.
# Ignoring reaction 'EX_cbasp_e' since it already exists.
# Ignoring reaction 'EX_cysam_e' since it already exists.
# Ignoring reaction 'EX_C04849_e' since it already exists.
# Ignoring reaction 'EX_CE1925_e' since it already exists.
# Ignoring reaction 'EX_CE5786_e' since it already exists.
# Ignoring reaction 'EX_CE5853_e' since it already exists.
# Ignoring reaction 'EX_CE5854_e' since it already exists.
# Ignoring reaction 'EX_CE5868_e' since it already exists.
# Ignoring reaction 'EX_HC01104_e' since it already exists.
# Ignoring reaction 'EX_HC01444_e' since it already exists.
# Ignoring reaction 'EX_HC01609_e' since it already exists.
# Ignoring reaction 'EX_HC02160_e' since it already exists.
# Ignoring reaction 'EX_HC02161_e' since it already exists.
# Ignoring reaction 'EX_pchol_cho_e' since it already exists.
# Ignoring reaction 'EX_ps_cho_e' since it already exists.
# Ignoring reaction 'EX_C03958_e' since it already exists.
# Ignoring reaction 'EX_CE5820_e' since it already exists.
# Ignoring reaction 'EX_psuri_e' since it already exists.
# Ignoring reaction 'EX_gudac_e' since it already exists.
# Ignoring reaction 'EX_L2aadp_e' since it already exists.
# Ignoring reaction 'EX_nicrnt_e' since it already exists.
# Ignoring reaction 'EX_orot5p_e' since it already exists.
# Ignoring reaction 'EX_lneldccrn_e' since it already exists.
# Ignoring reaction 'EX_pmtcrn_e' since it already exists.
# Ignoring reaction 'EX_pcreat_e' since it already exists.
# Ignoring reaction 'EX_bgly_e' since it already exists.
# Ignoring reaction 'EX_mi1p__D_e' since it already exists.
# Ignoring reaction 'EX_nwharg_e' since it already exists.
# Ignoring reaction 'EX_alaglylys_e' since it already exists.
# Ignoring reaction 'EX_argarg_e' since it already exists.
# Ignoring reaction 'EX_argphearg_e' since it already exists.
# Ignoring reaction 'EX_argvaltrp_e' since it already exists.
# Ignoring reaction 'EX_asnphecys_e' since it already exists.
# Ignoring reaction 'EX_asphiscys_e' since it already exists.
# Ignoring reaction 'EX_aspvalasn_e' since it already exists.
# Ignoring reaction 'EX_cysgluhis_e' since it already exists.
# Ignoring reaction 'EX_cysglutrp_e' since it already exists.
# Ignoring reaction 'EX_glntrpglu_e' since it already exists.
# Ignoring reaction 'EX_gluglu_e' since it already exists.
# Ignoring reaction 'EX_gluilelys_e' since it already exists.
# Ignoring reaction 'EX_glumet_e' since it already exists.
# Ignoring reaction 'EX_glumethis_e' since it already exists.
# Ignoring reaction 'EX_glyhislys_e' since it already exists.
# Ignoring reaction 'EX_hisglnala_e' since it already exists.
# Ignoring reaction 'EX_hisglu_e' since it already exists.
# Ignoring reaction 'EX_hisglugln_e' since it already exists.
# Ignoring reaction 'EX_ileargile_e' since it already exists.
# Ignoring reaction 'EX_ileglyarg_e' since it already exists.
# Ignoring reaction 'EX_ileserarg_e' since it already exists.
# Ignoring reaction 'EX_iletrptyr_e' since it already exists.
# Ignoring reaction 'EX_leuasnasp_e' since it already exists.
# Ignoring reaction 'EX_leutyrtyr_e' since it already exists.
# Ignoring reaction 'EX_lystyrile_e' since it already exists.
# Ignoring reaction 'EX_lysvaltrp_e' since it already exists.
# Ignoring reaction 'EX_metargleu_e' since it already exists.
# Ignoring reaction 'EX_metglntyr_e' since it already exists.
# Ignoring reaction 'EX_pheglnphe_e' since it already exists.
# Ignoring reaction 'EX_pheleuhis_e' since it already exists.
# Ignoring reaction 'EX_pheproarg_e' since it already exists.
# Ignoring reaction 'EX_phesertrp_e' since it already exists.
# Ignoring reaction 'EX_phetyrlys_e' since it already exists.
# Ignoring reaction 'EX_proargasp_e' since it already exists.
# Ignoring reaction 'EX_proargcys_e' since it already exists.
# Ignoring reaction 'EX_proasncys_e' since it already exists.
# Ignoring reaction 'EX_prolyspro_e' since it already exists.
# Ignoring reaction 'EX_provalgln_e' since it already exists.
# Ignoring reaction 'EX_serphelys_e' since it already exists.
# Ignoring reaction 'EX_thrargtyr_e' since it already exists.
# Ignoring reaction 'EX_thrhishis_e' since it already exists.
# Ignoring reaction 'EX_thrtyrmet_e' since it already exists.
# Ignoring reaction 'EX_trpglugly_e' since it already exists.
# Ignoring reaction 'EX_trpmetarg_e' since it already exists.
# Ignoring reaction 'EX_trpphe_e' since it already exists.
# Ignoring reaction 'EX_trpthrglu_e' since it already exists.
# Ignoring reaction 'EX_tyrargglu_e' since it already exists.
# Ignoring reaction 'EX_tyrphetyr_e' since it already exists.
# Ignoring reaction 'EX_valserarg_e' since it already exists.
# Ignoring reaction 'EX_trpglyasp_e' since it already exists.
# Ignoring reaction 'EX_CE4890_e' since it already exists.
# Ignoring reaction 'EX_alagly_e' since it already exists.
# Ignoring reaction 'EX_ala_his_e' since it already exists.
# Ignoring reaction 'EX_stfrnA_e' since it already exists.
# Ignoring reaction 'EX_stfrnB_e' since it already exists.
# Ignoring reaction 'EX_gly_met_e' since it already exists.
# Ignoring reaction 'EX_gly_tyr_e' since it already exists.
# Ignoring reaction 'EX_gly_gln_e' since it already exists.
# Ignoring reaction 'EX_gly_leu_e' since it already exists.
# Ignoring reaction 'EX_lysglugly_e' since it already exists.
# Ignoring reaction 'EX_prohisglu_e' since it already exists.
# Ignoring reaction 'EX_serglugly_e' since it already exists.
# Ignoring reaction 'EX_dtbt_e' since it already exists.
# Ignoring reaction 'EX_25dkglcn_e' since it already exists.
# Ignoring reaction 'EX_6hnac_e' since it already exists.
# Ignoring reaction 'EX_alatrp_e' since it already exists.
# Ignoring reaction 'EX_balabala_e' since it already exists.
# Ignoring reaction 'EX_balagly_e' since it already exists.
# Ignoring reaction 'EX_dgudbutn_e' since it already exists.
# Ignoring reaction 'EX_dmso2_e' since it already exists.
# Ignoring reaction 'EX_tyr__D_e' since it already exists.
# Ignoring reaction 'EX_ecto__L_e' since it already exists.
# Ignoring reaction 'EX_R_3hdda_e' since it already exists.
# Ignoring reaction 'EX_R_3hppta_e' since it already exists.
# Ignoring reaction 'EX_R_3hpt_e' since it already exists.
# Ignoring reaction 'EX_fe3pyovd_kt_e' since it already exists.
# Ignoring reaction 'EX_gudptn_e' since it already exists.
# Ignoring reaction 'EX_hpta_e' since it already exists.
# Ignoring reaction 'EX_nona_e' since it already exists.
# Ignoring reaction 'EX_phehxa_e' since it already exists.
# Ignoring reaction 'EX_pheocta_e' since it already exists.
# Ignoring reaction 'EX_sheme_e' since it already exists.
# Ignoring reaction 'EX_23dhb_e' since it already exists.
# Running ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:02:31
# Model building completed. Manifest:
#       sample_id                 file
# 0  TARA_ARC_108  TARA_ARC_108.pickle

# %%
from micom import load_pickle

cgem = load_pickle("../tests/test_docker_micom/TARA_ARC_108.pickle")
cgem
# Out:
# <Community TARA_ARC_108 at 0x7fea1dfe3340>

# %% [markdown]
# ## Computing trophic exchanges

# %%
# %%bash
#
# RESULTS_DIR="/home/robaina/Documents/NewAtlantis/microcom/tests/test_docker_micom"
#
# docker run --rm \
#   -v "${RESULTS_DIR}:/app/results" \
#   ghcr.io/new-atlantis-labs/micom:latest \
#   get_exchanges \
#   --manifest /app/results/manifest.csv \
#   --outdir /app/results \
#   --media_file /app/results/marine_media.tsv \
#   --growth_tradeoff 0.5 \
#   --threads 12 \
#   --out_exchanges /app/results/exchanges.tsv
# Out:
# Running ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:01:03
# Growth simulations completed.

# %% [markdown]
# ## Generate figures

# %%
# %%bash
#
# docker run \
#     -v /home/robaina/Documents/NewAtlantis/microcom/tests/test_docker_micom:/data \
#     -v /home/robaina/Documents/NewAtlantis/microcom/tests/test_docker_viz:/app/results \
#     ghcr.io/new-atlantis-labs/cgem-viz:latest \
#     --exchanges-file /data/exchanges.tsv \
#     --flux-cutoff "top10" \
#     --visualization-type network \

# %% [markdown]
# ![Figure 1](/home/robaina/Documents/NewAtlantis/microcom/tests/test_docker_viz/trophic_interactions.png)

# %%
# %%bash
#
# docker run \
#     -v /home/robaina/Documents/NewAtlantis/microcom/tests/test_docker_micom:/data \
#     -v /home/robaina/Documents/NewAtlantis/microcom/tests/test_docker_viz:/app/results \
#     ghcr.io/new-atlantis-labs/cgem-viz:latest \
#     --exchanges-file /data/exchanges.tsv \
#     --visualization-type heatmap \
#     --output-dir /app/results \
#     --normalize-heatmap \
#     --cluster-heatmap

# %% [markdown]
# ![Figure 2](/home/robaina/Documents/NewAtlantis/microcom/tests/test_docker_viz/exchange_heatmap.png)

# %%
# %%bash
#
# docker run \
#     -v /home/robaina/Documents/NewAtlantis/microcom/tests/test_docker_micom:/data \
#     -v /home/robaina/Documents/NewAtlantis/microcom/tests/test_docker_viz:/app/results \
#     ghcr.io/new-atlantis-labs/cgem-viz:latest \
#     --exchanges-file /data/exchanges.tsv \
#     --visualization-type sankey \
#     --output-dir /app/results \
#     --sankey-flux-cutoff 0.1

# %% [markdown]
# ![Figure 3](/home/robaina/Documents/NewAtlantis/microcom/tests/test_docker_viz/metabolic_sankey.png)
